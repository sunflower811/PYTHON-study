# %%
import requests
from requests import Response
a='https://data.moenv.gov.tw/api/v2/aqx_p_488?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=CSV'
r:Response=requests.get(a)
if r.ok:print('download successfully!!!')
# Out:
# download successfully!!!

# %%
#type(r.text)
import csv
from io import StringIO
data:str=r.text
file=StringIO(data)
dictReader=csv.DictReader(file,fieldnames=['sitename','county','aqi','status','pm2.5','datacreationdate','longigude'],restkey='NO')
next(dictReader)
datas:list[dict]=list(dictReader)
for site in datas:
    del site['NO']
    print(site)
# Out:
# {'sitename': '屏東(枋山)', 'county': '屏東縣', 'aqi': '101', 'status': '臭氧八小時', 'pm2.5': '對敏感族群不健康', 'datacreationdate': '0.4', 'longigude': '0.14'}
# {'sitename': '花蓮（美崙）', 'county': '花蓮縣', 'aqi': '35', 'status': '', 'pm2.5': '良好', 'datacreationdate': '0.2', 'longigude': '0.23'}
# {'sitename': '新北（樹林）', 'county': '新北市', 'aqi': '69', 'status': '二氧化氮', 'pm2.5': '普通', 'datacreationdate': '2', 'longigude': '0.65'}
# {'sitename': '台中市（和平區消防隊）', 'county': '臺中市', 'aqi': '56', 'status': '細懸浮微粒', 'pm2.5': '普通', 'datacreationdate': '0.7', 'longigude': '0.36'}
# {'sitename': '屏東（琉球）', 'county': '屏東縣', 'aqi': '84', 'status': '臭氧八小時', 'pm2.5': '普通', 'datacreationdate': '1.1', 'longigude': '0.21'}
# {'sitename': '臺南（麻豆）', 'county': '臺南市', 'aqi': '83', 'status': '懸浮微粒', 'pm2.5': '普通', 'datacreationdate': '1.1', 'longigude': '0.22'}
# {'sitename': '高雄（湖內）', 'county': '高雄市', 'aqi': '108', 'status': '細懸浮微粒', 'pm2.5': '對敏感族群不健康', 'datacreationdate': '1.9', 'longigude': '0.49'}
# ...

# %%
with open('aqi.csv',mode='w',encoding='utf-8',newline='') as file:
    dict_writer=csv.DictWriter(file,fieldnames=['sitename','county','aqi','status','pm2.5','datacreationdate','longigude'])
    dict_writer.writeheader()
    dict_writer.writerows(datas)
