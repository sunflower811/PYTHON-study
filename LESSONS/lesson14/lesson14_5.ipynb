# %%
import numpy as np
import pandas as pd
scores=np.random.randint(50,101,size=(50,5))
df1=pd.DataFrame(scores,
             columns=['Chinese','English','Math','Geography','History'],
             index=range(1,51))

# %%
df1.index.name='學號'
df1.columns.name='subjects'

# %%
df1.loc[1].sum()
# Out:
# np.int64(363)

# %%
sum=df1.sum(axis=1)

# %%
df1['總分']=sum
df1['average']=sum/5
df1
# Out:
# subjects  Chinese  English  Math  Geography  History   總分  average
# 學號
# 1              69       73    91         56       74  363     72.6
# 2              98       83    68         82       79  410     82.0
# 3              97       68    57         92       78  392     78.4
# 4              75       56    53         51       85  320     64.0
# 5              84       78    91         84       84  421     84.2
# 6              67       59    52         69       78  325     65.0
# 7              76       93    62        100       51  382     76.4
# 8              56       97   100         83       55  391     78.2
# 9              57       52    99         89       53  350     70.0
# 10             80       70    59         88       90  387     77.4
# 11             58       69    73         64       79  343     68.6
# 12             59       74    56         68       78  335     67.0
# 13             89       83    77         99       53  401     80.2
# ...

# %%
E_series=df1['English']<60
df1[E_series]
# Out:
# subjects  Chinese  English  Math  Geography  History   總分  average
# 學號
# 4              75       56    53         51       85  320     64.0
# 6              67       59    52         69       78  325     65.0
# 9              57       52    99         89       53  350     70.0
# 21             94       57    77         92       83  403     80.6
# 28             65       57    76         52       70  320     64.0
# 29             94       53    58         86       69  360     72.0
# 30             55       59    96         54       82  346     69.2
# 31             80       53    83         97       83  396     79.2
# 37             86       58    79         97       63  383     76.6
# 40             58       58    71         81       87  355     71.0
# 43             89       52    86         60       70  357     71.4
