# %%
import numpy as np
import pandas as pd
scores=np.random.randint(50,101,size=(50,5))
pd.DataFrame(scores,
             columns=['Chinese','English','Math','Geography','History'],
             index=range(1,51))
# Out:
#     Chinese  English  Math  Geography  History
# 1        56       52    72         67       70
# 2        75       72    73         53       52
# 3        97       66    85         71       99
# 4        50       72    71         61       96
# 5        86       66    70         84       69
# 6        93       59    86         87       71
# 7        78       72    74         90       82
# 8        78       81    89         81       85
# 9        69       51    79         89       64
# 10       69       93    60         97       84
# 11       95       90    66         54       78
# 12       67       53    68         96       67
# 13       76       77    61         94       86
# 14       90       53    76         85       71
# 15       59       78    97         61       66
# 16       57       74    71         83       74
# 17       63       61    77         69       90
# 18       84       70    57         90       54
# 19       61       92    56         79       89
# ...
